# %%
def my_function(f_name, l_name):
  print(f_name.title(), l_name.title())
  #print(l_name.title())

my_function(f_name= "LUCKY", l_name="shukla")
# Out:
# Lucky Shukla

# %%
def formate_name(f_name, l_name):
  formatted_f_name = f_name.title()
  formatted_l_name = l_name.title()
  return f"{formatted_f_name} {formatted_l_name}"

#print(formate_name(f_name="LUCky",l_name="SHuklA"))
print(formate_name("LUCky","SHuklA"))
# Out:
# Lucky Shukla

# %%
def function_1(text):
 return text+text

def function_2(text):
 return text.title()

#output = function_1("hello")
output = function_2(function_1("hello"))
print(output)
# Out:
# Hellohello

# %%
def formate_name(f_name, l_name):
  if f_name =="" or l_name=="":
    return "Invalid inputs"
  formatted_f_name = f_name.title()
  formatted_l_name = l_name.title()
  return f"Result:{formatted_f_name} {formatted_l_name}"

print(formate_name(f_name=input("Enter your first name"),l_name=input("Enter your last name")))
# Out:
# Enter your first namelucKY
# Enter your last namesHUKLA
# Result:Lucky Shukla
