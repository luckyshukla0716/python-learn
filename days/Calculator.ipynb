# %%
def add(a,b):
  return a+b

#my_addition_operator = add
#print(my_addition_operator(2,3))

def sub(a,b):
  return a-b

def mult(a,b):
  return a*b

def div(a,b):
  return a/b

operations = {
    "+": add,
    "-": sub,
    "*": mult,
    "/": div
}


def calculator():
  should_accumulate = True
  num1 = float(input("Enter the value of first num: "))

  while should_accumulate:
    for symbols in operations :
      print(symbols)

    operation_symbol = input("Enter the symbol of operation you want to perform ")

    num2 = float(input("Enter the value of second num: "))

    #print(f"{operations[operation_symbol](num1 , num2)}")
    answer = operations[operation_symbol](num1 , num2)
    print(f"{num1} {operation_symbol} {num2} = {answer} ")

    choice = input(f"Enter 'y' if you want to continue with the {answer} otherwise type 'n' for new calculations: ").lower()

    if choice == "y":
      num1= answer
    else:
      should_accumulate = False
      print("\n"  *20)
      calculator()

calculator()
# Out:
# Enter the value of first num: 1
# +
# -
# *
# /
# Enter the symbol of operation you want to perform +
# Enter the value of second num: 1
# 1.0 + 1.0 = 2.0
# Enter 'y' if you want to continue with the 2.0 otherwise type 'n' for new calculations: y
# +
# -
# *
# /
# Enter the symbol of operation you want to perform +
# Enter the value of second num: 5
# 2.0 + 5.0 = 7.0
# Enter 'y' if you want to continue with the 7.0 otherwise type 'n' for new calculations: n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Enter the value of first num: 4
# +
# -
# *
# /
# Enter the symbol of operation you want to perform -
# Enter the value of second num: 2
# 4.0 - 2.0 = 2.0
# Enter 'y' if you want to continue with the 2.0 otherwise type 'n' for new calculations: n
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1325/2614835821.py in <cell line: 0>()
#      47       calculator()
# ...
