# %%
#functions:
def animal():
  print("dog", "lion", "elephant")

animal()
# Out:
# dog lion elephant

# %%
"""def turn_right():
    turn_left()
    turn_left()
    turn_left()

def hurdle():
    move()
    turn_left()
    move()
    turn_right()
    move()
    turn_right()
    move()
    turn_left()

for jump in range(6):
    hurdle()

    #num_of_hurdels=6
while num_of_hurdels >0:
    hurdle()
    num_of_hurdels -=1
    print(num_of_hurdels)

# %%
''''#hurdel2---Reeborg's world
def turn_right():
    turn_left()
    turn_left()
    turn_left()

def hurdle():
    move()
    turn_left()
    move()
    turn_right()
    move()
    turn_right()
    move()
    turn_left()



while at_goal() != True:
    print(at_goal)

    hurdle()

# %%
''''##hurdle 3
def turn_right():
    turn_left()
    turn_left()
    turn_left()

def hurdle():
    turn_left()
    move()
    turn_right()
    move()
    turn_right()
    move()
    turn_left()


while not at_goal():
    if wall_in_front():
        hurdle()
    else:
        move()

# %%
""""hurdle 4
def turn_right():
    turn_left()
    turn_left()
    turn_left()

def hurdle():
    turn_left()
    while wall_on_right():
        move()
    turn_right()
    move()
    turn_right()
    while front_is_clear():
        move()
    turn_left()



while not at_goal():
    if wall_in_front():
        hurdle()
    else:
        move()
