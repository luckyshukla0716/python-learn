# %%
#modifying global scope
#global variable
enemies = 1

def increase_enemy():
  enemies =2 #local_variable
  print(f"Enemies inside function : {enemies}")

increase_enemy()
print(f"Enemies outside function : {enemies}")
# Out:
# Enemies inside function : 2
# Enemies outside function : 1

# %%
enemies = 1

def increase_enemy(current_enemies):
  print(f"Enemies inside function : {current_enemies}")
  return current_enemies + 1

enemies = increase_enemy(enemies)
print(f"Enemies outside function : {enemies}")
# Out:
# Enemies inside function : 1
# Enemies outside function : 2

# %%
i = 50
def foo():
    i = 100
    return i

foo()
print(i)
# Out:
# 50

# %%
def bar():
    my_variable = 9

    if 16 > 9:
      my_variable = 16

    print(my_variable)

bar()
# Out:
# 16

# %%
def a_function(a_parameter):
    a_variable = 15
    return a_parameter

a_function(10)
print(a_variable) # it shpuld give a error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_589/615173679.py in <cell line: 0>()
#       4
#       5 a_function(10)
# ----> 6 print(a_variable)
#
# NameError: name 'a_variable' is not defined
